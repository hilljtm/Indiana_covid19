# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pdvega
# %config InlineBackend.figure_format='retina'

# %%
# Load data
df = pd.read_csv('Data/covid19_county.csv')

# %%
df.head()
# Out:
#         County  Cases_17  Cases_18  Cases_19  Cases_20  Cases_21  Cases_22
# 0        Adams         1         1         1         1         1         1
# 1        Allen         0         0         1         4         4         6
# 2  Bartholomew         1         1         1         1         5         5
# 3        Boone         1         1         2         2         3         3
# 4        Clark         1         1         1         4         4         5

# %%
df.vgplot.bar(x='County',y='Cases_17')
# Out:
# <div class="vega-embed" id="4e3529bf-a303-45e1-ba94-37692ecf7710"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>

# %%
# Setting the positions and width for the bars

df = pd.read_csv('Data/covid19_county.csv')

pos = list(range(len(df['County']))) 
width = 0.25 
    
# Plotting the bars
fig, ax = plt.subplots(figsize=(15,10))

# Create a bar with Cases_17 data,
# in position pos,
plt.bar(pos, 
        #using df['Cases_17'] data,
        df['Cases_17'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#EE3224', 
        # with label the first value in County
        label=df['County'][0]) 

# Create a bar with Cases_18 data,
# in position pos + some width buffer,
plt.bar([p + width for p in pos], 
        #using df['Cases_18'] data,
        df['Cases_18'],
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#F78F1E', 
        # with label the second value in County
        label=df['County'][1]) 

# Create a bar with Cases_19 data,
# in position pos + some width buffer,
plt.bar([p + width*2 for p in pos], 
        #using df['Cases_19'] data,
        df['Cases_19'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#FFC222', 
        # with label the third value in County
        label=df['County'][2]) 

# Create a bar with Cases_20 data,
# in position pos + some width buffer,
plt.bar([p + width*2 for p in pos], 
        #using df['Cases_20'] data,
        df['Cases_20'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#FF5733', 
        # with label the fourth value in County
        label=df['County'][3])

# Create a bar with Cases_21 data,
# in position pos + some width buffer,
plt.bar([p + width*2 for p in pos], 
        #using df['Cases_21'] data,
        df['Cases_21'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#FF5733', 
        # with label the fifth value in County
        label=df['County'][4])



# Set the y axis label
ax.set_ylabel('Cases')

# Set the chart's title
ax.set_title('Covid19 cases in Indiana')

# Set the position of the x ticks
ax.set_xticks([p + 1.5 * width for p in pos])
plt.xticks(rotation=90)

# Set the labels for the x ticks
ax.set_xticklabels(df['County'])

# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, max(df['Cases_17'] + df['Cases_18'] + df['Cases_19'] + df['Cases_20'] + df['Cases_21'])] )

# Adding the legend and showing the plot
plt.legend(['March 17th', 'March 18th', 'March 19th', 'March 20th', 'March 21st'], loc='upper left')
plt.grid(True)
plt.show()
plt.savefig('covid.png', orientation='landscape', dpi=80)

# %%
df.vgplot.bar(x='County', stacked=True, interactive=True)
# Out:
# <div class="vega-embed" id="70f0587f-151e-4b22-a50f-5f3eb1d51bee"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
