# %%
import pandas as pd
import numpy as np
from plotly import graph_objs as go
import seaborn as sns
# %config InlineBackend.figure_format='retina'

# %%
# Load data
df = pd.read_csv('Data/covid19_county.csv')

# %%
df.head()
# Out:
#         County  Cases_17  Cases_18  Cases_19  Cases_20
# 0        Adams       1.0       1.0       1.0         1
# 1        Allen       NaN       NaN       1.0         4
# 2  Bartholomew       1.0       1.0       1.0         1
# 3        Boone       1.0       1.0       2.0         2
# 4        Clark       1.0       1.0       1.0         4

# %%
df.plot(x='County',y='Cases_17', kind='bar')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Load the example car crash dataset
df = pd.read_csv('Data/covid19_county.csv').sort_values(['County'], ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="Cases_17", y="County", data=df,
            label="March 17th", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="Cases_18", y="County", data=df,
            label="March 18th", color="b")

sns.set_color_codes("muted")
sns.barplot(x="Cases_19", y="County", data=df,
            label="March 19th", color="b")

sns.set_color_codes("muted")
sns.barplot(x="Cases_20", y="County", data=df,
            label="March 20th", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)

# %%
# Setting the positions and width for the bars

df = pd.read_csv('Data/covid19_county.csv')

pos = list(range(len(df['County']))) 
width = 0.25 
    
# Plotting the bars
fig, ax = plt.subplots(figsize=(15,10))

# Create a bar with Cases_17 data,
# in position pos,
plt.bar(pos, 
        #using df['Cases_17'] data,
        df['Cases_17'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#EE3224', 
        # with label the first value in County
        label=df['County'][0]) 

# Create a bar with Cases_18 data,
# in position pos + some width buffer,
plt.bar([p + width for p in pos], 
        #using df['Cases_18'] data,
        df['Cases_18'],
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#F78F1E', 
        # with label the second value in County
        label=df['County'][1]) 

# Create a bar with Cases_19 data,
# in position pos + some width buffer,
plt.bar([p + width*2 for p in pos], 
        #using df['Cases_19'] data,
        df['Cases_19'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#FFC222', 
        # with label the third value in County
        label=df['County'][2]) 

# Create a bar with Cases_20 data,
# in position pos + some width buffer,
plt.bar([p + width*2 for p in pos], 
        #using df['Cases_20'] data,
        df['Cases_20'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#FF5733', 
        # with label the fourth value in County
        label=df['County'][3])

# Set the y axis label
ax.set_ylabel('Cases')

# Set the chart's title
ax.set_title('Covid19 cases in Indiana')

# Set the position of the x ticks
ax.set_xticks([p + 1.5 * width for p in pos])
plt.xticks(rotation=90)

# Set the labels for the x ticks
ax.set_xticklabels(df['County'])

# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, max(df['Cases_17'] + df['Cases_18'] + df['Cases_19'] + df['Cases_20'])] )

# Adding the legend and showing the plot
plt.legend(['March 17th', 'March 18th', 'March 19th', 'March 20th'], loc='upper left')
plt.grid(True)
plt.show()
plt.savefig('covid.png', orientation='landscape', dpi=80)
